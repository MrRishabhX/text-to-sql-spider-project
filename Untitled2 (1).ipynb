# %%
# ==== 1. Mount Google Drive ====
from google.colab import drive
drive.mount('/content/drive')

# ==== 2. Install Hugging Face datasets library ====
# !pip install datasets --quiet

# ==== 3. Authenticate with Hugging Face ====
from huggingface_hub import login

# Paste your Hugging Face read token (get it from https://huggingface.co/settings/tokens)
# Make sure you've accepted the BookSQL license terms on Hugging Face
login(token="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")

# ==== 4. Load BookSQL dataset ====
from datasets import load_dataset

booksql = load_dataset("Exploration-Lab/BookSQL")  # train/validation/test splits
print(booksql)

# ==== 5. Save dataset to Google Drive (Hugging Face format) ====
save_path_hf = "/content/drive/MyDrive/TextToSQL_Project/booksql_dataset"
booksql.save_to_disk(save_path_hf)
print(f"✅ BookSQL dataset saved to: {save_path_hf}")

# ==== 6. Also save as CSV and JSONL for inspection ====
csv_train_path = "/content/drive/MyDrive/TextToSQL_Project/booksql_train.csv"
csv_val_path = "/content/drive/MyDrive/TextToSQL_Project/booksql_val.csv"

json_train_path = "/content/drive/MyDrive/TextToSQL_Project/booksql_train.jsonl"
json_val_path = "/content/drive/MyDrive/TextToSQL_Project/booksql_val.jsonl"

booksql['train'].to_csv(csv_train_path, index=False)
booksql['validation'].to_csv(csv_val_path, index=False)

booksql['train'].to_json(json_train_path, orient="records", lines=True)
booksql['validation'].to_json(json_val_path, orient="records", lines=True)

print("✅ BookSQL saved as CSV and JSONL in Google Drive")

# ==== 7. Reload later without redownloading (Hugging Face format) ====
from datasets import load_from_disk
booksql_reloaded = load_from_disk(save_path_hf)
print("✅ Reloaded BookSQL dataset from Drive")
print(booksql_reloaded)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# README.md:   0%|          | 0.00/2.96k [00:00<?, ?B/s]
# BookSQL/train.json:   0%|          | 0.00/26.8M [00:00<?, ?B/s]
# val.json:   0%|          | 0.00/3.11M [00:00<?, ?B/s]
# test.json:   0%|          | 0.00/2.86M [00:00<?, ?B/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating validation split: 0 examples [00:00, ? examples/s]
# Generating test split: 0 examples [00:00, ? examples/s]
# ---------------------------------------------------------------------------
# CastError                                 Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/datasets/builder.py in _prepare_split_single(self, gen_kwargs, fpath, file_format, max_shard_size, job_id)
#    1830                     try:
# -> 1831                         writer.write_table(table)
# ...
